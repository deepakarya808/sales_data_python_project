# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"C:\Users\LENOVO\Desktop\dataanalysisgit\SalesAnalysis\Output\all_data.csv")

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
data.iloc[519]
# Out:
# Order ID                    Order ID
# Product                      Product
# Quantity Ordered    Quantity Ordered
# Price Each                Price Each
# Order Date                Order Date
# Purchase Address    Purchase Address
# Name: 519, dtype: object

# %%
data["Order Date"] = pd.to_datetime(data["Order Date"],errors ='coerce',format="mixed")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        185950 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 8.6+ MB

# %% [markdown]
# ### Finding Null Values

# %%
nan_df = data[data.isnull().any(axis=1)]

# %%
nan_df
# Out:
#         Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 1            NaN      NaN               NaN         NaN        NaT
# 356          NaN      NaN               NaN         NaN        NaT
# 519     Order ID  Product  Quantity Ordered  Price Each        NaT
# 735          NaN      NaN               NaN         NaN        NaT
# 1149    Order ID  Product  Quantity Ordered  Price Each        NaT
# ...          ...      ...               ...         ...        ...
# 186548       NaN      NaN               NaN         NaN        NaT
# 186563  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186632  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186738  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186826       NaN      NaN               NaN         NaN        NaT
#
#         Purchase Address
# 1                    NaN
# 356                  NaN
# 519     Purchase Address
# 735                  NaN
# 1149    Purchase Address
# ...

# %% [markdown]
# ### Dropping null Values

# %%
data = data.dropna(how="all")

# %%
data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# 5   176561            Wired Headphones                1      11.99
#
#            Order Date                      Purchase Address
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ### Adding Month Column

# %%
data["Month"] = data["Order Date"].dt.month

# %%
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address  Month
# ...

# %%
data.isnull().sum()
# Out:
# Order ID              0
# Product               0
# Quantity Ordered      0
# Price Each            0
# Order Date          355
# Purchase Address      0
# Month               355
# dtype: int64

# %%
data= data.dropna(how="all")

# %%
data.isnull().sum()
# Out:
# Order ID              0
# Product               0
# Quantity Ordered      0
# Price Each            0
# Order Date          355
# Purchase Address      0
# Month               355
# dtype: int64

# %% [markdown]
# ### Filling Null Values

# %%
new_nans = data[data.isna().any(axis=1)]

# %%
new_nans
# Out:
#         Order ID  Product  Quantity Ordered  Price Each Order Date  \
# 519     Order ID  Product  Quantity Ordered  Price Each        NaT
# 1149    Order ID  Product  Quantity Ordered  Price Each        NaT
# 1155    Order ID  Product  Quantity Ordered  Price Each        NaT
# 2878    Order ID  Product  Quantity Ordered  Price Each        NaT
# 2893    Order ID  Product  Quantity Ordered  Price Each        NaT
# ...          ...      ...               ...         ...        ...
# 185164  Order ID  Product  Quantity Ordered  Price Each        NaT
# 185551  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186563  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186632  Order ID  Product  Quantity Ordered  Price Each        NaT
# 186738  Order ID  Product  Quantity Ordered  Price Each        NaT
#
#         Purchase Address  Month
# 519     Purchase Address    NaN
# 1149    Purchase Address    NaN
# 1155    Purchase Address    NaN
# ...

# %%
data.bfill(inplace=True)

# %%
data.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# Month               0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Month             186305 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(5)
# memory usage: 11.4+ MB

# %%
data["Month"] = data["Month"].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Month             186305 non-null  int32
# dtypes: datetime64[ns](1), int32(1), object(5)
# memory usage: 10.7+ MB

# %%
data
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# 5        176561            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#                 Order Date                         Purchase Address  Month
# ...

# %% [markdown]
# ### Adding a sales column

# %%
data["Quantity Ordered"] = pd.to_numeric(data["Quantity Ordered"],errors ='coerce')

# %%
data["Price Each"]= pd.to_numeric(data["Price Each"],errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        186305 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Month             186305 non-null  int32
# dtypes: datetime64[ns](1), float64(2), int32(1), object(3)
# memory usage: 10.7+ MB

# %%
data["Sales"] = data["Quantity Ordered"]*data["Price Each"]

# %% [markdown]
# ### Adding Hours and Minutes Column

# %%
data["Hour"] = data["Order Date"].dt.hour

# %%
data["Minutes"] = data["Order Date"].dt.minute

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes
# 0     8       46
# 2    22       30
# 3    14       38
# 4    14       38
# ...

# %%
data[["Street Address","City","Zip"]] = data["Purchase Address"].str.split(',',expand= True)

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address          City        Zip
# ...

# %%
data.Zip
# Out:
# 0          TX 75001
# 2          MA 02215
# 3          CA 90001
# 4          CA 90001
# 5          CA 90001
#             ...
# 186845     CA 90001
# 186846     CA 94016
# 186847     CA 94016
# 186848     CA 94016
# 186849     CA 94016
# Name: Zip, Length: 186305, dtype: object

# %%
data[["Zip1","zip2","zip3"]]= data["Zip"].str.split(' ',expand=True)

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address          City        Zip Zip1 zip2   zip3
# ...

# %%
data["City"]= data["City"]+' '+data["zip2"]

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address             City        Zip Zip1 zip2   zip3
# ...

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address             City        Zip Zip1 zip2   zip3
# ...

# %%
data.drop(["Zip1","zip2","zip3"],axis=1,inplace=True)

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address             City        Zip
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 186305 entries, 0 to 186849
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  185950 non-null  float64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        186305 non-null  datetime64[ns]
#  5   Purchase Address  186305 non-null  object
#  6   Month             186305 non-null  int32
#  7   Sales             185950 non-null  float64
#  8   Hour              186305 non-null  int32
#  9   Minutes           186305 non-null  int32
#  10  Street Address    186305 non-null  object
#  11  City              185950 non-null  object
#  12  Zip               185950 non-null  object
# dtypes: datetime64[ns](1), float64(3), int32(3), object(6)
# memory usage: 17.8+ MB

# %% [markdown]
# ### Q1 = Which month has the highest sales?

# %%
monthresult = data.groupby("Month")[["Quantity Ordered","Price Each","Sales"]].sum().reset_index()

# %%
monthresult
# Out:
#     Month  Quantity Ordered  Price Each       Sales
# 0       1           10903.0  1811768.38  1822256.73
# 1       2           13449.0  2188884.72  2202022.42
# 2       3           17005.0  2791207.83  2807100.38
# 3       4           20558.0  3367671.02  3390670.24
# 4       5           18667.0  3135125.13  3152606.75
# 5       6           15253.0  2562025.61  2577802.26
# 6       7           16072.0  2632539.56  2647775.76
# 7       8           13448.0  2230345.42  2244467.88
# 8       9           13109.0  2084992.09  2097560.13
# 9      10           22703.0  3715554.83  3736726.88
# 10     11           19798.0  3180600.68  3199603.20
# 11     12           28114.0  4588415.41  4613443.34

# %%
Month=range(1,13)
plt.figure(figsize=(6,3))

plt.bar(Month,monthresult["Sales"])

plt.show()

# %% [markdown]
# ### Which city has the highest sales?

# %%
result= data.groupby("City")[["Quantity Ordered","Price Each","Sales"]].sum().reset_index()

# %%
result
# Out:
#                 City  Quantity Ordered  Price Each       Sales
# 0         Atlanta GA           16602.0  2779908.20  2795498.58
# 1          Austin TX           11153.0  1809873.61  1819581.75
# 2          Boston MA           22528.0  3637409.77  3661642.01
# 3          Dallas TX           16730.0  2752627.82  2767975.40
# 4     Los Angeles CA           33289.0  5421435.23  5452570.80
# 5   New York City NY           27932.0  4635370.83  4664317.43
# 6        Portland ME            2750.0   447189.25   449758.27
# 7        Portland OR           11303.0  1860558.22  1870732.34
# 8   San Francisco CA           50239.0  8211461.74  8262203.91
# 9         Seattle WA           16553.0  2733296.01  2747755.48

# %%
cities= [city for city,df in data.groupby("City")]
plt.bar(cities,result["Sales"])
plt.xticks(cities,rotation="vertical",size=10)
plt.ylabel("Sales in USD($)")
plt.xlabel("City")

plt.show()

# %% [markdown]
# ### What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
hours= [hour for hour,df in data.groupby("Hour")]
plt.plot(hours,data.groupby(["Hour"]).count())
plt.xticks(hours,size=10)
plt.grid()
plt.xlabel("Hour")
plt.ylabel("Sales")
plt.show()

# %% [markdown]
# ### Which product sold the most?

# %%
data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable               2.0       11.95
# 2   176559  Bose SoundSport Headphones               1.0       99.99
# 3   176560                Google Phone               1.0      600.00
# 4   176560            Wired Headphones               1.0       11.99
# 5   176561            Wired Headphones               1.0       11.99
#
#            Order Date                      Purchase Address  Month   Sales  \
# 0 2019-04-19 08:46:00          917 1st St, Dallas, TX 75001      4   23.90
# 2 2019-04-07 22:30:00     682 Chestnut St, Boston, MA 02215      4   99.99
# 3 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 4 2019-04-12 14:38:00  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 5 2019-04-30 09:27:00     333 8th St, Los Angeles, CA 90001      4   11.99
#
#    Hour  Minutes   Street Address             City        Zip
# ...

# %%
products= data.groupby("Product")[["Quantity Ordered","Price Each","Sales"]].sum().reset_index().sort_values(by="Sales",ascending=False)

# %%
products
# Out:
#                        Product  Quantity Ordered  Price Each       Sales
# 13          Macbook Pro Laptop            4728.0  8030800.00  8037600.00
# 19                      iPhone            6849.0  4789400.00  4794300.00
# 15             ThinkPad Laptop            4130.0  4127958.72  4129958.70
# 9                 Google Phone            5532.0  3315000.00  3319200.00
# 1       27in 4K Gaming Monitor            6244.0  2429637.70  2435097.56
# 3       34in Ultrawide Monitor            6199.0  2348718.19  2355558.01
# 6     Apple Airpods Headphones           15661.0  2332350.00  2349150.00
# 8                Flatscreen TV            4819.0  1440000.00  1445700.00
# 7   Bose SoundSport Headphones           13457.0  1332366.75  1345565.43
# 2             27in FHD Monitor            7550.0  1125974.93  1132424.50
# 17             Vareebadd Phone            2068.0   826000.00   827200.00
# 0                 20in Monitor            4129.0   451068.99   454148.71
# ...

# %%
sns.barplot(x="Product",y="Quantity Ordered",data=products)
plt.xticks(rotation="vertical",size=10)
plt.show()
